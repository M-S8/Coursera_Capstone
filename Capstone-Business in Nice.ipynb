# %% [markdown]
# # Setting up a business in the city of Nice in the Cote d'Azur region of France

# %% [markdown]
# ### 1.BUSINESS PROBLEM:
#
# ### A client  wants to invest in  a business in Nice.Nice is a very popular destination for tourists for its exquisite beaches and warm coastal temperature throughout the year.
# ### Before investing,he wants to get an idea of the popular venues of Nice.This will help the client in deciding the type of business he would like to invest in.
#
#
# ### Background study of Nice:
#
# ### Côte d'Azur is a coastal region of southeastern France. It includes famously many popular beach resorts such as Saint-Tropez , Cannes, Nice and Antibes,to name a few.
#
# ### The map of Cote d'Azur region:
# ![Cote%20d%20azur.jpg](attachment:Cote%20d%20azur.jpg)
#
# ### The following data of Nice has been obtained from the site:https://en.meet-in-nice.com/key-figures
#
#
#   * ### Nice receives visitors from the whole wolrd, and has all the necessary facilities to further develop its capabilities.
#   * ### Number one tourist destination after Paris.
#   * ### Around 5 million visitors per year.
#   * ### 40% of the tourist flow on the French Riviera, worth 1.5 billion in economic benefits.
#   * ### Leading conference city in France after Paris.
#   * ### One of the highest number of hotel rooms, and the best quality accommodation after Paris, accounting for a third of french riviera stays.
#   * ### One of the top French cruise ports: Nice/Villefranche-sur-Mer with 487 440 passengers and over 300 ships mooring in the port each year.
#   * ### Highest concentration of museums after Paris, with 19 museums and art galleries.
#   * ### 1st city in France with vineyards within the city limits.
#
#
# ### The following statistics gives an insight into the trends of tourism in France(Source-Statista)
# ### 1. Number of tourists who visited France from 2010-2018:
# ![france%20tourism%20stats.jpg](attachment:france%20tourism%20stats.jpg)
#
# ### 2.Regions of France based on their popularity among tourists:
# ![france%20region%20stats.jpg](attachment:france%20region%20stats.jpg)
#
# ### From above statistics ,we can see that tourism is on the rise in France and Cote d'azur is the third most popular region among tourists
#
#
# ## Possible Stakeholders:
# ### This project is going to be an interest to anyone or any group who is looking forward to investing in a business in Nice. In post-pandemic world, tourism is going to rise again as people will be more than happy to step outside and explore and break free from the confinements of their homes.The French Riviera in Nice has been drawing thousands and thousands of tourists every year and a business that will cater to the needs of tourists is surely going to be successful here.

# %% [markdown]
# ## 2. DATA SECTION:
# ## Let's start by exploring the Nice city

# %% [markdown]
# ### 1.First we need the coordinates of the city.For this we use the Geopy python package to convert an address into respective latitude and longitude.Once we have the coordinates,we will use Foursquare API to explore the city to find popular venues.
#
# ![coords.jpg](attachment:coords.jpg)

# %% [markdown]
# ## To get an idea of popular venues in Nice,we will make use of Foursquare API data.
# ### By using the explore endpoint ,we find the popular venues in Nice.
#
#
# ![Nice%20venues.jpg](attachment:Nice%20venues.jpg)

# %% [markdown]
# ## Using the Folium library we build a map to get a look at the locations of popular venues of Nice
#
# ![Nice%20map.jpg](attachment:Nice%20map.jpg)

# %% [markdown]
# ### Then we find the number of venues present in each category using the value_counts() method.This is important to know which venues are present in more numbers and which in less.
# ![Nice%20venue%20count.jpg](attachment:Nice%20venue%20count.jpg)
#
# ### From the above data we can see that the three most popular venues are:
# ### 1.French restaurants
# ### 2.Icecream shops
# ### 3.Hotels & wine bars
#
# ### Since Nice is a very popular tourist destination,we can see from the above data that restaurants are in demand there.So investing in a restaurant business might be a good business idea.

# %% [markdown]
# ## Now we will use Foursquare API to get the popular restaurants in Nice.
# ## Below is the list of ten popular restaurants:
# ![Nice%20restaurants.jpg](attachment:Nice%20restaurants.jpg)
#
# ### We can see that there are restaurants of variety of cuisines given that Nice is a very popular tourist destination and people from all over the world come to visit this place.

# %% [markdown]
# ## Let's find the number of restaurants in each cuisine using the value_counts() on 'categories' column
# ![Nice%20restaurants%20count.jpg](attachment:Nice%20restaurants%20count.jpg)
#
# ### From the above data, we can see that French restaurants are the maximum in numbers.This is obvious because its the local cuisine.
# ### Italian cuisine is enjoyed all over the world so no wonder Italian restaurants are second most popular in Nice.
# ### Third most common is Indian cuisine restaurant.

# %% [markdown]
# ### Using Folium we can visualize the location of these restaurants.This will give an idea to clients to select a proper location to set up their restaurant business.
#
# ![fnice%20resta%20map.jpg](attachment:fnice%20resta%20map.jpg)
